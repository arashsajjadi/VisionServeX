# %%
# v2.53.0: RTMPose COCO keypoints benchmark models.
# GT-box top-down evaluation — measures pose estimator accuracy with perfect person localization.
RTMPOSE_BENCHMARK_MODELS = [
    "rtmpose-s", "rtmpose-m", "rtmpose-l",  # benchmark_passed via 271-img COCO keypoints mini
    "rtmpose-m-384x288", "rtmpose-l-384x288",  # benchmark_failed: config not in mim registry
    "rtmpose-t",  # benchmark_failed: mim downloaded CrowdPose config (14-kp) not COCO
]
print(f"RTMPose models tracked: {len(RTMPOSE_BENCHMARK_MODELS)}")
print("Dataset: coco-keypoints:/home/arash/datasets/coco_keypoints_val_mini_vsx")
print("Box source: gt-person-boxes (GT-box top-down — NOT end-to-end)")
