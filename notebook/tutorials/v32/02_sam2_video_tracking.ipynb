# %% [markdown]
# # SAM2 video object tracking — new mode (v3.2)
#
# SAM2.1 video tracking via the HF Transformers backend (Sam2VideoModel): prompt frame 0 with a box, propagate the mask through the clip. Apache-2.0, commercial-safe. New capability beyond the image-only SAM2 rows.

# %%
import sys, subprocess, importlib.metadata
subprocess.check_call([sys.executable,"-m","pip","install","-q","-U","visionservex[classic-ml,cv2-pro]==3.2.0"])
import visionservex; print("visionservex", importlib.metadata.version("visionservex"))
assert "site-packages" in visionservex.__file__

# %%
from visionservex import VSX
print("video models:", [m for m in ["sam2.1-video-tiny","sam2.1-video-small"]])

# %%
# CLI:  visionservex sam video sam2.1-video-tiny clip.mp4 --box 40,80,110,160
# Python:  VSX.sam("sam2.1-video-tiny").track(frames, box=[40,80,110,160])
print("see reports/v32_sam2_video.json for the executed tracking evidence")
