# %% [markdown]
# # v3.9 — DINOv3 ViT-S/16 BYOT embedding
#
# Requires: accepted DINOv3 license on HF Hub + `visionservex[hf]`.

# %%
from visionservex import VSX
result = VSX.dino('dinov3-vits16').embed('tests/assets/smoke/coco_person_car.jpg')
print(result)

# %%
from pathlib import Path
import json
artifact = Path('notebook/99_final_report/artifacts/v39/dinov3/dinov3-vits16/metadata.json')
if artifact.exists():
    print(json.loads(artifact.read_text()))
