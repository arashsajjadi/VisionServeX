# %% [markdown]
# # v3.9 — DINOv3 large variants: ViT-L, ViT-H, ViT-7B
#
# ViT-7B requires CPU (~28GB RAM). ViT-H needs 16GB VRAM or CPU.

# %%
import json
from pathlib import Path
for mid in ['dinov3-vitl16', 'dinov3-vith16plus', 'dinov3-vit7b16']:
    meta = Path(f'notebook/99_final_report/artifacts/v39/dinov3/{mid}/metadata.json')
    if meta.exists():
        d = json.loads(meta.read_text())
        print(f"{mid}: shape={d.get('embedding_shape')} params={d.get('params_millions')}M device={d.get('device')}")
    else:
        print(f'{mid}: artifact not yet available')
