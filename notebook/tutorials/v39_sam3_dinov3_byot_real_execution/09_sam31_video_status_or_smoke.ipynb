# %% [markdown]
# # v3.9 — SAM3.1 video tracking status
#
# SAM3.1 video mode requires large RAM. Check status before running.

# %%
from visionservex import VSX
status = VSX.model('sam3.1-video').status()
print('Status:', status)

# %%
# Video tracking requires the sam3.1-video runtime path
# Access granted but weights are the same multiplex checkpoint
# Recommend: run with VISIONSERVEX_RUN_HEAVY_GATED=1 on a 32GB+ VRAM machine
print('resource_plan: sam3.1-video tracking is resource-heavy; use CPU or high-VRAM GPU')
