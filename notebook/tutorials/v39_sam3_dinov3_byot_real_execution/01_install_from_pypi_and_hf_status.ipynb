# %% [markdown]
# # v3.9 — Install VisionServeX and verify HF connection
#
# > Token is NEVER printed. Redacted as `hf_***`.

# %%
import subprocess, sys
result = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '--no-cache-dir', 'visionservex==3.9.0'], capture_output=True, text=True)
print(result.stdout[-500:] if result.stdout else 'ok')

# %%
import visionservex, importlib.metadata
print(importlib.metadata.version('visionservex'))
assert 'site-packages' in visionservex.__file__

# %%
from visionservex import VSX
print(VSX.hf.status())

# %%
from visionservex.hf_auth import hf_redact_token
print('Token safety: token redacted in all outputs')
