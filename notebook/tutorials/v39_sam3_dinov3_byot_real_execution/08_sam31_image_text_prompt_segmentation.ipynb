# %% [markdown]
# # v3.9 — SAM3.1 BYOT text-prompt segmentation
#
# SAM3.1 uses a multiplex checkpoint (`sam3.1_multiplex.pt`).

# %%
from visionservex import VSX
result = VSX.sam('sam3.1-base').segment('tests/assets/smoke/coco_person_car.jpg', text='person')
print(result)
