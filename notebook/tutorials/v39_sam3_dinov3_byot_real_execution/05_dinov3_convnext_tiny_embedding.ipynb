# %% [markdown]
# # v3.9 — DINOv3 ConvNeXt-Tiny BYOT embedding

# %%
from visionservex import VSX
result = VSX.dino('dinov3-convnext-tiny').embed('tests/assets/smoke/coco_person_car.jpg')
print(result)
