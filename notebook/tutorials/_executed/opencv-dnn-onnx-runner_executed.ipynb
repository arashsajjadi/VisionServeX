# %% [markdown]
# # CV2-Pro tutorial — opencv-dnn-onnx-runner
#
# Weight-free OpenCV tool **opencv-dnn-onnx-runner** (Apache-2.0, CPU). Runs on the base install. Use for region proposals / mask refinement in annotation pipelines.

# %% [markdown]
# ## Fresh pip-install verification (imports from site-packages, not local src)

# %%
import sys, subprocess, importlib.metadata
VERSION = "3.1.0"
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U",
    f"visionservex[classic-ml,cv2-pro]=={VERSION}"])
import visionservex
print("visionservex", importlib.metadata.version("visionservex"))
print("file:", visionservex.__file__)
assert "site-packages" in visionservex.__file__, visionservex.__file__
assert "PycharmProjects/VisionServeX/src" not in visionservex.__file__
# Out:
# visionservex 3.1.0
# file: /tmp/vsx_v31b/lib/python3.13/site-packages/visionservex/__init__.py
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
try:
    import cv2
except Exception:
    cv2=None
from visionservex.cv2_pro import run_tool, tool_available, TOOL_LICENSE
print("tool:", "opencv-dnn-onnx-runner", "| available:", tool_available("opencv-dnn-onnx-runner"), "| license:", TOOL_LICENSE().get("opencv-dnn-onnx-runner"))
# Out:
# tool: opencv-dnn-onnx-runner | available: (True, 'ok') | license: OpenCV Apache-2.0

# %%
if cv2 is not None and tool_available("opencv-dnn-onnx-runner")[0]:
    img=(np.random.default_rng(0).normal(120,30,(192,192,3))).clip(0,255).astype("uint8")
    params={"box":[30,30,160,160]} if "opencv-dnn-onnx-runner"=="opencv-grabcut-plus" else {}
    r=run_tool("opencv-dnn-onnx-runner", img, **params)
    print({k:v for k,v in r.items() if k!="polygons"})
else:
    print("install: pip install 'visionservex[cv2-pro]'")
# Out:
# {'status': 'no_onnx_provided', 'hint': 'pass onnx=<path>.onnx', 'dnn_backends': 3, 'tool': 'opencv-dnn-onnx-runner', 'kind': 'onnx', 'device': 'cpu', 'license_safe': True, 'license': 'OpenCV Apache-2.0', 'latency_ms': 0.013}
