# %% [markdown]
# # SAM tutorial — hq-sam (legal review)
#
# **hq-sam**: Apache-2.0 code, but training-data provenance (HQSeg-44K non-commercial / SA-1B research) means it stays `legal_review_required` (NOT commercial-safe core) until reviewed.

# %% [markdown]
# ## Fresh pip-install verification (imports from site-packages, not local src)

# %%
import sys, subprocess, importlib.metadata
VERSION = "3.1.0"
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U",
    f"visionservex[classic-ml,cv2-pro]=={VERSION}"])
import visionservex
print("visionservex", importlib.metadata.version("visionservex"))
print("file:", visionservex.__file__)
assert "site-packages" in visionservex.__file__, visionservex.__file__
assert "PycharmProjects/VisionServeX/src" not in visionservex.__file__
# Out:
# visionservex 3.1.0
# file: /tmp/vsx_v31b/lib/python3.13/site-packages/visionservex/__init__.py
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from visionservex import VSX
sam = VSX.sam("hq-sam")
import json; print(json.dumps(sam.explain(), indent=2, default=str))
print("Use lawfully:", sam.explain()["next_command"])
# Out:
# {
#   "model_id": "hq-sam",
#   "family": "sam",
#   "task": "promptable_segmentation",
#   "state": "legal_review_required",
#   "license": "Apache-2.0 code; HQSeg-44K/SA-1B training-data review",
#   "install_extra": "visionservex[sam2,promptable]",
#   "prompt_types": [
#     "box",
#     "points",
#     "mask"
#   ],
#   "auth_required": false,
#   "output_schema": {
#     "masks": "list[HxW uint8]",
#     "scores": "list[float]",
#     "polygons": "optional"
#   },
#   "limitations": "video/text prompts require SAM2-video / SAM3 (gated)",
#   "next_command": "visionservex legal review hq-sam",
#   "tutorial": "notebook/tutorials/sam_family/hq-sam.ipynb"
# }
# Use lawfully: visionservex legal review hq-sam
