# %% [markdown]
# # DINO tutorial — dino-x-api (api)
#
# **dino-x-api**: DINO-X is API-only — external; weights never mirrored.

# %% [markdown]
# ## Fresh pip-install verification (imports from site-packages, not local src)

# %%
import sys, subprocess, importlib.metadata
VERSION = "3.1.0"
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U",
    f"visionservex[classic-ml,cv2-pro]=={VERSION}"])
import visionservex
print("visionservex", importlib.metadata.version("visionservex"))
print("file:", visionservex.__file__)
assert "site-packages" in visionservex.__file__, visionservex.__file__
assert "PycharmProjects/VisionServeX/src" not in visionservex.__file__
# Out:
# visionservex 3.1.0
# file: /tmp/vsx_v31_fresh/lib/python3.13/site-packages/visionservex/__init__.py

# %%
from visionservex import VSX
import json; print(json.dumps(VSX.dino("dino-x-api").explain(), indent=2, default=str))
# Out:
# {
#   "model_id": "dino-x-api",
#   "family": "dino",
#   "task": "open_vocab_detect",
#   "state": "external_api_only",
#   "license": "proprietary/closed (API)",
#   "install_extra": "visionservex[foundation,open-vocab]",
#   "auth_required": true,
#   "output_schema": {
#     "boxes": "xyxy",
#     "scores": "list",
#     "labels": "list"
#   },
#   "limitations": "DINOv3 is custom-licensed (gated); GroundingDINO 1.5/1.6 are API/token-gated",
#   "next_command": "export DEEPDATASPACE_API_KEY=... && visionservex dino api dino-x-api image.jpg --text '...'",
#   "tutorial": "notebook/tutorials/dino_family/dino-x-api.ipynb"
# }
