# %% [markdown]
# # Pipeline tutorial — grounding-dino-swin-b+sam2.1-hiera-large
#
# Text-to-mask pipeline **grounding-dino-swin-b+sam2.1-hiera-large**: GroundingDINO detects by text, SAM segments each box. First-class via `VSX.pipeline(...)` / `visionservex pipeline run`.

# %% [markdown]
# ## Fresh pip-install verification (imports from site-packages, not local src)

# %%
import sys, subprocess, importlib.metadata
VERSION = "3.1.0"
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U",
    f"visionservex[classic-ml,cv2-pro]=={VERSION}"])
import visionservex
print("visionservex", importlib.metadata.version("visionservex"))
print("file:", visionservex.__file__)
assert "site-packages" in visionservex.__file__, visionservex.__file__
assert "PycharmProjects/VisionServeX/src" not in visionservex.__file__
# Out:
# visionservex 3.1.0
# file: /tmp/vsx_v31b/lib/python3.13/site-packages/visionservex/__init__.py
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from visionservex import VSX
pipe = VSX.pipeline("grounding-dino-swin-b+sam2.1-hiera-large")
import json; print(json.dumps(pipe.explain(), indent=2, default=str))
print("state:", pipe.status())
# Out:
# {
#   "pipeline_id": "grounding-dino-swin-b+sam2.1-hiera-large",
#   "kind": "text_to_mask",
#   "state": "pipeline_demo_ready",
#   "detector": "grounding-dino-swin-b",
#   "detector_state": "benchmark_passed",
#   "segmenter": "sam2.1-hiera-large",
#   "segmenter_state": "benchmark_passed",
#   "license": "Apache-2.0 + Apache-2.0 (commercial-safe)",
#   "next_command": "visionservex pipeline run grounding-dino-swin-b+sam2.1-hiera-large image.jpg --text 'defect' --out runs/out",
#   "limitations": "gated component => the pipeline inherits auth_required",
#   "tutorial": "notebook/tutorials/pipelines/grounding-dino-swin-b_sam2.1-hiera-large.ipynb"
# }
# state: pipeline_demo_ready
