# %% [markdown]
# # Interactive-seg tutorial — simpleclick (legal_review_required)
#
# **simpleclick** interactive click segmentation. Code is permissive; weights are non-commercial (MAE/SegFormer NC) -> legal review.

# %% [markdown]
# ## Fresh pip-install verification (imports from site-packages, not local src)

# %%
import sys, subprocess, importlib.metadata
VERSION = "3.1.0"
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U",
    f"visionservex[classic-ml,cv2-pro]=={VERSION}"])
import visionservex
print("visionservex", importlib.metadata.version("visionservex"))
print("file:", visionservex.__file__)
assert "site-packages" in visionservex.__file__, visionservex.__file__
assert "PycharmProjects/VisionServeX/src" not in visionservex.__file__
# Out:
# visionservex 3.1.0
# file: /tmp/vsx_v31b/lib/python3.13/site-packages/visionservex/__init__.py
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Honest state: legal_review_required. License audit: notebook/99_final_report/reports/v31_web_research_evidence.csv
print("model: simpleclick | state: legal_review_required")
print("next: visionservex interactive-seg status simpleclick")
# Out:
# model: simpleclick | state: legal_review_required
# next: visionservex interactive-seg status simpleclick
