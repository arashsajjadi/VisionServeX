# %% [markdown]
# # SAM tutorial — medsam2 (sidecar)
#
# **medsam2** runs in an isolated sidecar environment (Apache-2.0). Build it with the sidecar manager.

# %% [markdown]
# ## Fresh pip-install verification (imports from site-packages, not local src)

# %%
import sys, subprocess, importlib.metadata
VERSION = "3.1.0"
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U",
    f"visionservex[classic-ml,cv2-pro]=={VERSION}"])
import visionservex
print("visionservex", importlib.metadata.version("visionservex"))
print("file:", visionservex.__file__)
assert "site-packages" in visionservex.__file__, visionservex.__file__
assert "PycharmProjects/VisionServeX/src" not in visionservex.__file__
# Out:
# visionservex 3.1.0
# file: /tmp/vsx_v31b/lib/python3.13/site-packages/visionservex/__init__.py
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from visionservex import VSX
print(VSX.sam("medsam2").explain())
# Out:
# {'model_id': 'medsam2', 'family': 'sam', 'task': 'promptable_segmentation', 'state': 'sidecar_required', 'license': 'Apache-2.0', 'install_extra': 'visionservex[sam2,promptable]', 'prompt_types': ['box', 'points', 'mask'], 'auth_required': False, 'output_schema': {'masks': 'list[HxW uint8]', 'scores': 'list[float]', 'polygons': 'optional'}, 'limitations': 'video/text prompts require SAM2-video / SAM3 (gated)', 'next_command': 'visionservex sidecar create medsam2 --execute', 'tutorial': 'notebook/tutorials/sam_family/medsam2.ipynb'}
