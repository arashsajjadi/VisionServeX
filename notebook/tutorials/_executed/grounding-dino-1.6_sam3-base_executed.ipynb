# %% [markdown]
# # Pipeline tutorial — grounding-dino-1.6+sam3-base
#
# Text-to-mask pipeline **grounding-dino-1.6+sam3-base**: GroundingDINO detects by text, SAM segments each box. First-class via `VSX.pipeline(...)` / `visionservex pipeline run`.

# %% [markdown]
# ## Fresh pip-install verification (imports from site-packages, not local src)

# %%
import sys, subprocess, importlib.metadata
VERSION = "3.1.0"
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U",
    f"visionservex[classic-ml,cv2-pro]=={VERSION}"])
import visionservex
print("visionservex", importlib.metadata.version("visionservex"))
print("file:", visionservex.__file__)
assert "site-packages" in visionservex.__file__, visionservex.__file__
assert "PycharmProjects/VisionServeX/src" not in visionservex.__file__
# Out:
# visionservex 3.1.0
# file: /tmp/vsx_v31_fresh/lib/python3.13/site-packages/visionservex/__init__.py

# %%
from visionservex import VSX
pipe = VSX.pipeline("grounding-dino-1.6+sam3-base")
import json; print(json.dumps(pipe.explain(), indent=2, default=str))
print("state:", pipe.status())
# Out:
# {
#   "pipeline_id": "grounding-dino-1.6+sam3-base",
#   "kind": "text_to_mask",
#   "state": "auth_required",
#   "detector": "grounding-dino-1.6",
#   "detector_state": "auth_required",
#   "segmenter": "sam3-base",
#   "segmenter_state": "auth_required",
#   "license": "API/gated + SAM License (Meta custom, HF-gated)",
#   "next_command": "visionservex pipeline run grounding-dino-1.6+sam3-base image.jpg --text 'defect' --out runs/out",
#   "limitations": "gated component => the pipeline inherits auth_required",
#   "tutorial": "notebook/tutorials/pipelines/grounding-dino-1.6_sam3-base.ipynb"
# }
# state: auth_required
