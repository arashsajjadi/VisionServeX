# %% [markdown]
# # CV2-Pro tutorial — opencv-selective-search-fast
#
# Weight-free OpenCV tool **opencv-selective-search-fast** (Apache-2.0, CPU). Requires the cv2-pro extra (opencv-contrib). Use for region proposals / mask refinement in annotation pipelines.

# %% [markdown]
# ## Fresh pip-install verification (imports from site-packages, not local src)

# %%
import sys, subprocess, importlib.metadata
VERSION = "3.1.0"
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U",
    f"visionservex[classic-ml,cv2-pro]=={VERSION}"])
import visionservex
print("visionservex", importlib.metadata.version("visionservex"))
print("file:", visionservex.__file__)
assert "site-packages" in visionservex.__file__, visionservex.__file__
assert "PycharmProjects/VisionServeX/src" not in visionservex.__file__
# Out:
# visionservex 3.1.0
# file: /tmp/vsx_v31_fresh/lib/python3.13/site-packages/visionservex/__init__.py

# %%
import numpy as np
try:
    import cv2
except Exception:
    cv2=None
from visionservex.cv2_pro import run_tool, tool_available, TOOL_LICENSE
print("tool:", "opencv-selective-search-fast", "| available:", tool_available("opencv-selective-search-fast"), "| license:", TOOL_LICENSE().get("opencv-selective-search-fast"))
# Out:
# tool: opencv-selective-search-fast | available: (True, 'ok') | license: OpenCV Apache-2.0

# %%
if cv2 is not None and tool_available("opencv-selective-search-fast")[0]:
    img=(np.random.default_rng(0).normal(120,30,(192,192,3))).clip(0,255).astype("uint8")
    params={"box":[30,30,160,160]} if "opencv-selective-search-fast"=="opencv-grabcut-plus" else {}
    r=run_tool("opencv-selective-search-fast", img, **params)
    print({k:v for k,v in r.items() if k!="polygons"})
else:
    print("install: pip install 'visionservex[cv2-pro]'")
# Out:
# {'n_proposals': 51, 'boxes_xyxy': [[158, 50, 177, 69], [0, 0, 192, 192], [0, 143, 21, 157], [0, 0, 130, 192], [180, 100, 192, 120], [56, 100, 74, 116], [147, 64, 192, 157], [129, 36, 153, 50], [120, 77, 165, 150], [175, 96, 192, 117], [99, 144, 192, 192], [68, 0, 192, 98], [122, 74, 144, 90], [26, 31, 130, 192], [120, 124, 147, 152], [31, 0, 62, 7], [82, 181, 111, 192], [58, 56, 74, 77], [31, 0, 63, 18], [180, 100, 192, 115], [113, 96, 125, 113], [25, 175, 38, 192], [0, 177, 13, 192], [106, 64, 192, 157], [77, 124, 139, 179], [14, 0, 83, 49], [136, 160, 159, 180], [0, 0, 73, 192], [23, 40, 45, 62], [75, 0, 94, 18], [7, 0, 192, 192], [14, 0, 83, 62], [58, 0, 192, 98], [150, 160, 192, 192], [7, 0, 28, 20], [29, 22, 40, 39], [105, 109, 119, 129], [120, 77, 165, 152], [165, 0, 180, 13], [106, 65, 137, 86], [7, 0, 192, 98], [77, 124, 192, 192], [7, 0, 94, 62], [82, 144, 192, 192], [14, 0, 94, 62], [113, 77, 165, 152], [136, 160, 192, 192], [120, 64, 192, 157], [106, 65, 165, 152], [77, 64, 192, 192], [7, 0, 83, 62]], 'tool': 'opencv-selective-search-fast', 'kind': 'proposals', 'device': 'cpu', 'license_safe': True, 'license': 'OpenCV Apache-2.0', 'latency_ms': 175.549}
